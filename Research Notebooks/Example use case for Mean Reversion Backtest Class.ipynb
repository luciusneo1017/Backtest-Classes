# %%
from pathlib import Path
import sys
parent = Path.cwd().resolve().parents[0]
sys.path.append(str(parent))
from MeanReversionBacktestClass import MRVectorBacktest as MR
import pandas as pd
import requests
import re

# %%
start_date = '2022-01-01'
end_date = '2025-01-01'

# We need to ensure that, for whatever backtest window we choose, price data is available for every stock so the performance comparison is fair and measured over the same exact period. 
# Therefore, the earliest valid start date should be the latest common date for which data for all 101 assets of the Nasday 100 are available.

# %% [markdown]
# # Getting the yahoo finance tickers for all stocks in the Nasdaq 100

# %%
url = "https://en.wikipedia.org/wiki/Nasdaq-100"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 "
                  "(KHTML, like Gecko) Chrome/120.0 Safari/537.36"
}

html = requests.get(url, headers=headers, timeout=30).text
tables = pd.read_html(html)

components = next(df for df in tables if "Ticker" in df.columns)
tickers = components["Ticker"].tolist()

# Yahoo Finance uses '-' instead of '.' for tickers like BRK.B -> BRK-B
tickers = [t.replace(".", "-") for t in tickers]

print(len(tickers))
print(tickers[:15])
# Out:
# 101
# ['ADBE', 'AMD', 'ABNB', 'GOOGL', 'GOOG', 'AMZN', 'AEP', 'AMGN', 'ADI', 'AAPL', 'AMAT', 'APP', 'ARM', 'ASML', 'AZN']
# C:\Users\luciu\AppData\Local\Temp\ipykernel_31816\317895948.py:9: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)

# %%
summary_dict = {}
for ticker in tickers: 
    bt = MR(ticker,window=20
            ,entry= 2.0, exit = 0.5,start=start_date,end=end_date)
    summary_dict[ticker] = bt.run_strategy()

print(summary_dict)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# {'ADBE': {'sharpe': 0.777542389633536, 'cagr': '17.88%', 'cstrat': '63.48%', 'crets': '-21.21%', 'alpha': '84.69%', 'params': {'entry': 2.0, 'exit': 0.5, 'window': 20}}, 'AMD': {'sharpe': 0.5965075856286609, 'cagr': '21.75%', 'cstrat': '80.04%', 'crets': '-19.60%', 'alpha': '99.65%', 'params': {'entry': 2.0, 'exit': 0.5, 'window': 20}}, 'ABNB': {'sharpe': 0.41761640211908047, 'cagr': '12.47%', 'cstrat': '42.05%', 'crets': '-23.90%', 'alpha': '65.95%', 'params': {'entry': 2.0, 'exit': 0.5, 'window': 20}}, 'GOOGL': {'sharpe': 0.5591542167080346, 'cagr': '11.31%', 'cstrat': '37.75%', 'crets': '31.03%', 'alpha': '6.72%', 'params': {'entry': 2.0, 'exit': 0.5, 'window': 20}}, 'GOOG': {'sharpe': 0.3907799823609583, 'cagr': '7.53%', 'cstrat': '24.22%', 'crets': '31.74%', 'alpha': '-7.52%', 'params': {'entry': 2.0, 'exit': 0.5, 'window': 20}}, 'AMZN': {'sharpe': 0.4892990456337993, 'cagr': '11.93%', 'cstrat': '40.03%', 'crets': '28.75%', 'alpha': '11.28%', 'params': {'entry': 2.0, 'exit': 0.5, 'window': 20}}, 'AEP': {'sharpe': -0.02005494349988877, 'cagr': '-0.26%', 'cstrat': '-0.79%', 'crets': '16.60%', 'alpha': '-17.39%', 'params': {'entry': 2.0, 'exit': 0.5, 'window': 20}}, 'AMGN': {'sharpe': -0.4813619552845148, 'cagr': '-6.91%', 'cstrat': '-19.26%', 'crets': '26.43%', 'alpha': '-45.68%', 'params': {'entry': 2.0, 'exit': 0.5, 'window': 20}}, 'ADI': {'sharpe': 1.0394467565774048, 'cagr': '21.20%', 'cstrat': '77.65%', 'crets': '26.64%', 'alpha': '51.00%', 'params': {'entry': 2.0, 'exit': 0.5, 'window': 20}}, 'AAPL': {'sharpe': -0.5272062173192745, 'cagr': '-7.53%', 'cstrat': '-20.87%', 'crets': '39.84%', 'alpha': '-60.71%', 'params': {'entry': 2.0, 'exit': 0.5, 'window': 20}}, 'AMAT': {'sharpe': 0.5259153756629091, 'cagr': '14.71%', 'cstrat': '50.68%', 'crets': '4.39%', 'alpha': '46.28%', 'params': {'entry': 2.0, 'exit': 0.5, 'window': 20}}, 'APP': {'sharpe': -0.9152808627293023, 'cagr': '-39.73%', 'cstrat': '-77.97%', 'crets': '243.11%', 'alpha': '-321.08%', 'params': {'entry': 2.0, 'exit': 0.5, 'window': 20}}, 'ARM': {'sharpe': -0.5352873280984912, 'cagr': '-24.98%', 'cstrat': '-31.12%', 'crets': '93.99%', 'alpha': '-125.12%', 'params': {'entry': 2.0, 'exit': 0.5, 'window': 20}}, 'ASML': {'sharpe': 0.28597611703383424, 'cagr': '7.83%', 'cstrat': '25.27%', 'crets': '-10.43%', 'alpha': '35.70%', 'params': {'entry': 2.0, 'exit': 0.5, 'window': 20}}, 'AZN': {'sharpe': -0.5799825494180526, 'cagr': '-8.82%', 'cstrat': '-24.10%', 'crets': '20.00%', 'alpha': '-44.10%', 'params': {'entry': 2.0, 'exit': 0.5, 'window': 20}}, 'TEAM': {'sharpe': -0.1051869870397403, 'cagr': '-4.24%', 'cstrat': '-12.15%', 'crets': '-30.55%', 'alpha': '18.39%', 'params': {'entry': 2.0, 'exit': 0.5, 'window': 20}}, 'ADSK': {'sharpe': 0.841645640805066, 'cagr': '20.49%', 'cstrat': '74.55%', 'crets': '4.18%', 'alpha': '70.37%', 'params': {'entry': 2.0, 'exit': 0.5, 'window': 20}}, 'ADP': {'sharpe': -0.026273480489605653, 'cagr': '-0.33%', 'cstrat': '-0.97%', 'crets': '27.77%', 'alpha': '-28.75%', 'params': {'entry': 2.0, 'exit': 0.5, 'window': 20}}, 'AXON': {'sharpe': -0.36463040666985325, 'cagr': '-9.67%', 'cstrat': '-26.21%', 'crets': '288.77%', 'alpha': '-314.98%', 'params': {'entry': 2.0, 'exit': 0.5, 'window': 20}}, 'BKR': {'sharpe': -0.30075247245458614, 'cagr': '-6.66%', 'cstrat': '-18.61%', 'crets': '76.69%', 'alpha': '-95.30%', 'params': {'entry': 2.0, 'exit': 0.5, 'window': 20}}, 'BIIB': {'sharpe': 0.5030606653870452, 'cagr': '8.35%', 'cstrat': '27.06%', 'crets': '-37.36%', 'alpha': '64.43%', 'params': {'entry': 2.0, 'exit': 0.5, 'window': 20}}, 'BKNG': {'sharpe': 0.5210792840875104, 'cagr': '13.06%', 'cstrat': '44.33%', 'crets': '103.64%', 'alpha': '-59.32%', 'params': {'entry': 2.0, 'exit': 0.5, 'window': 20}}, 'AVGO': {'sharpe': 0.5818327590448804, 'cagr': '13.98%', 'cstrat': '47.85%', 'crets': '273.94%', 'alpha': '-226.09%', 'params': {'entry': 2.0, 'exit': 0.5, 'window': 20}}, 'CDNS': {'sharpe': 0.6663059603032191, 'cagr': '15.00%', 'cstrat': '51.85%' ...

# %%
def pct_to_float(x):
    """
    Converts pcts to decimals (float)
    """
    if isinstance(x, str) and x.strip().endswith("%"):
        return float(x.strip().replace("%", ""))
    return float(x)

def screener_top20(results: dict, metric: str, n: int = 20, ascending: bool = False) -> pd.DataFrame:
    """
    ranks by one of 'sharpe','cagr','cstrat','crets','alpha'
    ascending: False gives top (largest). True gives bottom (smallest).
    """
    rows = []
    for ticker, d in results.items():
        row = {"ticker": ticker}

        # metrics
        for k in ["sharpe", "cagr", "cstrat", "crets", "alpha"]:
            if k in d:
                row[k] = d[k]

        # params (optional)
        params = d.get("params", {})
        row["entry"] = params.get("entry")
        row["exit"] = params.get("exit")
        row["window"] = params.get("window")

        rows.append(row)

    df = pd.DataFrame(rows).set_index("ticker")

    # numeric sort key (convert percent strings to floats)
    if metric in ["cagr", "cstrat", "crets", "alpha"]:
        df[metric + "_num"] = df[metric].map(pct_to_float)
        sort_col = metric + "_num"
    else:
        df[metric + "_num"] = df[metric].astype(float)
        sort_col = metric + "_num"

    out = df.sort_values(sort_col, ascending=ascending).head(n)

    # show clean columns
    cols = ["sharpe", "cagr", "cstrat", "crets", "alpha", "entry", "exit", "window"]
    return out[cols]

# %% [markdown]
# # Top 20 by Sharpe

# %%
print("Top 20 by Sharpe")
print(screener_top20(summary_dict, "sharpe"))
# Out:
# Top 20 by Sharpe
#           sharpe    cagr   cstrat    crets    alpha  entry  exit  window
# ticker
# KLAC    1.164729  33.50%  137.12%   49.81%   87.31%    2.0   0.5      20
# CSCO    1.148896  16.04%   55.96%    2.88%   53.08%    2.0   0.5      20
# CDW     1.046634  15.51%   53.87%  -12.05%   65.92%    2.0   0.5      20
# ADI     1.039447  21.20%   77.65%   26.64%   51.00%    2.0   0.5      20
# MAR     0.985063  16.66%   58.48%   74.75%  -16.28%    2.0   0.5      20
# PEP     0.960958  10.77%   35.74%   -4.18%   39.92%    2.0   0.5      20
# INTU    0.920699  20.36%   73.98%    1.47%   72.51%    2.0   0.5      20
# GFS     0.898735  33.27%  135.87%  -35.70%  171.57%    2.0   0.5      20
# MNST    0.869635  13.34%   45.36%    8.89%   36.48%    2.0   0.5      20
# ADSK    0.841646  20.49%   74.55%    4.18%   70.37%    2.0   0.5      20
# PANW    0.809106  28.78%  112.95%  100.61%   12.34%    2.0   0.5      20
# ADBE    0.777542  17.88%   63.48%  -21.21%   84.69%    2.0   0.5      20
# MRVL    0.769947  31.04%  124.27%   25.13%   99.14%    2.0   0.5      20
# TXN     0.712030  11.71%   39.23%    7.31%   31.93%    2.0   0.5      20
# CDNS    0.666306  15.00%   51.85%   64.04%  -12.19%    2.0   0.5      20
# FTNT    0.661225  17.20%   60.66%   41.81%   18.85%    2.0   0.5      20
# LRCX    0.658527  20.68%   75.38%    3.25%   72.12%    2.0   0.5      20
# SNPS    0.658423  14.99%   51.78%   34.41%   17.37%    2.0   0.5      20
# QCOM    0.632391  17.26%   60.91%  -11.76%   72.67%    2.0   0.5      20
# PYPL    0.608878  16.90%   59.47%  -56.22%  115.68%    2.0   0.5      20

# %% [markdown]
# # Top 20 by CAGR

# %%
print("Top 20 by CAGR")
print(screener_top20(summary_dict, "cagr"))
# Out:
# Top 20 by CAGR
#           sharpe    cagr   cstrat    crets    alpha  entry  exit  window
# ticker
# KLAC    1.164729  33.50%  137.12%   49.81%   87.31%    2.0   0.5      20
# GFS     0.898735  33.27%  135.87%  -35.70%  171.57%    2.0   0.5      20
# MRVL    0.769947  31.04%  124.27%   25.13%   99.14%    2.0   0.5      20
# PANW    0.809106  28.78%  112.95%  100.61%   12.34%    2.0   0.5      20
# SHOP    0.513325  25.02%   94.91%  -22.00%  116.90%    2.0   0.5      20
# AMD     0.596508  21.75%   80.04%  -19.60%   99.65%    2.0   0.5      20
# ADI     1.039447  21.20%   77.65%   26.64%   51.00%    2.0   0.5      20
# LRCX    0.658527  20.68%   75.38%    3.25%   72.12%    2.0   0.5      20
# ZS      0.529152  20.61%   75.06%  -40.23%  115.28%    2.0   0.5      20
# ADSK    0.841646  20.49%   74.55%    4.18%   70.37%    2.0   0.5      20
# INTU    0.920699  20.36%   73.98%    1.47%   72.51%    2.0   0.5      20
# TTD     0.473421  20.23%   73.41%   30.43%   42.98%    2.0   0.5      20
# MU      0.594484  18.69%   66.85%  -10.43%   77.28%    2.0   0.5      20
# ADBE    0.777542  17.88%   63.48%  -21.21%   84.69%    2.0   0.5      20
# ON      0.518830  17.38%   61.43%  -10.15%   71.58%    2.0   0.5      20
# QCOM    0.632391  17.26%   60.91%  -11.76%   72.67%    2.0   0.5      20
# WBD     0.428923  17.24%   60.84%  -58.27%  119.11%    2.0   0.5      20
# FTNT    0.661225  17.20%   60.66%   41.81%   18.85%    2.0   0.5      20
# PYPL    0.608878  16.90%   59.47%  -56.22%  115.68%    2.0   0.5      20
# MAR     0.985063  16.66%   58.48%   74.75%  -16.28%    2.0   0.5      20

# %% [markdown]
# # Top 20 by Total Return

# %%
print("Top 20 by Total Return (crets)")
print(screener_top20(summary_dict, "crets"))
# Out:
# Top 20 by Total Asset Return (crets)
#           sharpe     cagr   cstrat    crets     alpha  entry  exit  window
# ticker
# CEG    -0.692134  -16.74%  -41.70%  447.81%  -489.51%    2.0   0.5      20
# MSTR   -0.544749  -32.23%  -68.73%  418.79%  -487.52%    2.0   0.5      20
# NVDA   -0.286270   -9.19%  -25.03%  346.58%  -371.60%    2.0   0.5      20
# PLTR   -0.159162   -6.63%  -18.53%  308.15%  -326.68%    2.0   0.5      20
# AXON   -0.364630   -9.67%  -26.21%  288.77%  -314.98%    2.0   0.5      20
# AVGO    0.581833   13.98%   47.85%  273.94%  -226.09%    2.0   0.5      20
# APP    -0.915281  -39.73%  -77.97%  243.11%  -321.08%    2.0   0.5      20
# BKNG    0.521079   13.06%   44.33%  103.64%   -59.32%    2.0   0.5      20
# PANW    0.809106   28.78%  112.95%  100.61%    12.34%    2.0   0.5      20
# PCAR    0.097361    1.46%    4.41%  100.47%   -96.06%    2.0   0.5      20
# TMUS   -0.423847   -5.50%  -15.55%   96.60%  -112.15%    2.0   0.5      20
# ARM    -0.535287  -24.98%  -31.12%   93.99%  -125.12%    2.0   0.5      20
# VRTX    0.608145    8.84%   28.79%   80.96%   -52.17%    2.0   0.5      20
# CTAS    0.016878    0.25%    0.76%   77.34%   -76.58%    2.0   0.5      20
# BKR    -0.300752   -6.66%  -18.61%   76.69%   -95.30%    2.0   0.5      20
# MAR     0.985063   16.66%   58.48%   74.75%   -16.28%    2.0   0.5      20
# META   -0.638629  -16.08%  -40.77%   73.61%  -114.38%    2.0   0.5      20
# PDD    -0.052629   -2.51%   -7.32%   72.89%   -80.20%    2.0   0.5      20
# CRWD    0.353859   12.70%   42.95%   72.52%   -29.57%    2.0   0.5      20
# FANG    0.337383    6.98%   22.33%   72.33%   -50.00%    2.0   0.5      20

# %% [markdown]
# # Top 20 by Strategy Total Return

# %%
print("Top 20 by Strategy Total Return (cstrat)")
print(screener_top20(summary_dict, "cstrat"))
# Out:
# Top 20 by Strategy Total Return (cstrat)
#           sharpe    cagr   cstrat    crets    alpha  entry  exit  window
# ticker
# KLAC    1.164728  33.50%  137.12%   49.81%   87.31%    2.0   0.5      20
# GFS     0.898735  33.27%  135.87%  -35.70%  171.57%    2.0   0.5      20
# MRVL    0.769947  31.04%  124.27%   25.13%   99.14%    2.0   0.5      20
# PANW    0.809106  28.78%  112.95%  100.61%   12.34%    2.0   0.5      20
# SHOP    0.513325  25.02%   94.91%  -22.00%  116.90%    2.0   0.5      20
# AMD     0.596508  21.75%   80.04%  -19.60%   99.65%    2.0   0.5      20
# ADI     1.039445  21.20%   77.65%   26.64%   51.00%    2.0   0.5      20
# LRCX    0.658527  20.68%   75.38%    3.25%   72.12%    2.0   0.5      20
# ZS      0.529152  20.61%   75.06%  -40.23%  115.28%    2.0   0.5      20
# ADSK    0.841646  20.49%   74.55%    4.18%   70.37%    2.0   0.5      20
# INTU    0.920700  20.36%   73.98%    1.47%   72.51%    2.0   0.5      20
# TTD     0.473421  20.23%   73.41%   30.43%   42.98%    2.0   0.5      20
# MU      0.594485  18.69%   66.85%  -10.43%   77.28%    2.0   0.5      20
# ADBE    0.777542  17.88%   63.48%  -21.21%   84.69%    2.0   0.5      20
# ON      0.518830  17.38%   61.43%  -10.15%   71.58%    2.0   0.5      20
# QCOM    0.632390  17.26%   60.91%  -11.76%   72.67%    2.0   0.5      20
# WBD     0.428923  17.24%   60.84%  -58.27%  119.11%    2.0   0.5      20
# FTNT    0.661225  17.20%   60.66%   41.81%   18.85%    2.0   0.5      20
# PYPL    0.608878  16.90%   59.47%  -56.22%  115.68%    2.0   0.5      20
# MAR     0.985064  16.66%   58.48%   74.75%  -16.28%    2.0   0.5      20

# %% [markdown]
# # Top 20 by Alpha (outperformance)

# %%
print("Top 20 by Alpha")
print(screener_top20(summary_dict, "alpha"))
# Out:
# Top 20 by Alpha
#           sharpe    cagr   cstrat    crets    alpha  entry  exit  window
# ticker
# GFS     0.898735  33.27%  135.87%  -35.70%  171.57%    2.0   0.5      20
# WBD     0.428923  17.24%   60.84%  -58.27%  119.11%    2.0   0.5      20
# SHOP    0.513325  25.02%   94.91%  -22.00%  116.90%    2.0   0.5      20
# PYPL    0.608878  16.90%   59.47%  -56.22%  115.68%    2.0   0.5      20
# ZS      0.529152  20.61%   75.06%  -40.23%  115.28%    2.0   0.5      20
# AMD     0.596508  21.75%   80.04%  -19.60%   99.65%    2.0   0.5      20
# MRVL    0.769947  31.04%  124.27%   25.13%   99.14%    2.0   0.5      20
# KLAC    1.164728  33.50%  137.12%   49.81%   87.31%    2.0   0.5      20
# ADBE    0.777542  17.88%   63.48%  -21.21%   84.69%    2.0   0.5      20
# MU      0.594485  18.69%   66.85%  -10.43%   77.28%    2.0   0.5      20
# QCOM    0.632390  17.26%   60.91%  -11.76%   72.67%    2.0   0.5      20
# INTU    0.920700  20.36%   73.98%    1.47%   72.51%    2.0   0.5      20
# LRCX    0.658527  20.68%   75.38%    3.25%   72.12%    2.0   0.5      20
# ON      0.518830  17.38%   61.43%  -10.15%   71.58%    2.0   0.5      20
# DDOG    0.421404  16.45%   57.63%  -12.78%   70.41%    2.0   0.5      20
# ADSK    0.841646  20.49%   74.55%    4.18%   70.37%    2.0   0.5      20
# ABNB    0.417616  12.47%   42.05%  -23.90%   65.95%    2.0   0.5      20
# CDW     1.046632  15.51%   53.87%  -12.05%   65.92%    2.0   0.5      20
# BIIB    0.503061   8.35%   27.06%  -37.36%   64.43%    2.0   0.5      20
# INTC    0.038061   0.93%    2.80%  -59.37%   62.17%    2.0   0.5      20
