# %%
import yfinance as yf
from SMA import SMAVectorBacktester as SMA
# Out:
# /Users/lucius/github/BacktestClasses/SMA.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   raw = yf.download(self.symbol, start = self.start, end = self.end)
# [*********************100%***********************]  1 of 1 completed

# %%
data = yf.download('EURUSD=X', start = '2023-12-01', end = '2025-06-30')
data
# Out:
# /var/folders/9q/5mth65fs50q30lwhn0tw6wnc0000gn/T/ipykernel_36229/3086342022.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download('EURUSD=X', start = '2023-12-01', end = '2025-06-30')
# [*********************100%***********************]  1 of 1 completed
# Price          Close      High       Low      Open   Volume
# Ticker      EURUSD=X  EURUSD=X  EURUSD=X  EURUSD=X EURUSD=X
# Date
# 2023-12-01  1.089206  1.091346  1.083154  1.089206        0
# 2023-12-04  1.088815  1.088732  1.080567  1.088815        0
# 2023-12-05  1.083776  1.084834  1.078260  1.083776        0
# 2023-12-06  1.079366  1.080369  1.077319  1.079366        0
# 2023-12-07  1.076670  1.079680  1.075766  1.076670        0
# ...              ...       ...       ...       ...      ...
# 2025-06-23  1.150086  1.155175  1.145554  1.150086        0
# 2025-06-24  1.159904  1.163589  1.158292  1.159904        0
# 2025-06-25  1.161224  1.163142  1.159098  1.161224        0
# 2025-06-26  1.168374  1.174343  1.166861  1.168374        0
# 2025-06-27  1.169221  1.175088  1.168429  1.169221        0
#
# [408 rows x 5 columns]

# %%
L = SMA('EURUSD=X', 42,252,'2023-12-01','2025-06-30')
# Out:
# /Users/lucius/github/BacktestClasses/SMA.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   raw = yf.download(self.symbol, start = self.start, end = self.end)
# [*********************100%***********************]  1 of 1 completed

# %%
L.run_strategy()
# Out:
# (0.96, -0.15)

# %%
# %%time
L.optimize_parameters((30,50,2),(200,300,2))
# Out:
# CPU times: user 521 ms, sys: 6.51 ms, total: 528 ms
# Wall time: 532 ms
# 'opt: [ 34. 250.], grossperf: 1.04'

# %%
L.plot_results()
